# %%
import pandas as pd
import os

folder_path = './out/data'
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
files
# Out:
# ['data_random.csv', 'alldata.csv', 'data_reinforce.csv']

# %%
all_data = pd.DataFrame()
for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    all_data = pd.concat([all_data, df], ignore_index=True)

# %%
all_data = all_data.drop_duplicates()
all_data
# Out:
#       core  l1i_size  l1d_size  l2_size  l1d_assoc  l1i_assoc  l2_assoc  \
# 0      5.0       3.0       6.0      7.0        4.0        4.0       4.0
# 1      7.0       3.0       9.0      6.0        4.0        4.0       1.0
# 2      9.0       5.0       3.0     11.0        1.0        1.0       1.0
# 3      1.0       8.0       5.0     12.0        1.0        2.0       4.0
# 4      8.0       7.0       5.0     16.0        2.0        4.0       3.0
# ...    ...       ...       ...      ...        ...        ...       ...
# 1160   1.0       7.0       5.0      6.0        2.0        4.0       1.0
# 1170   1.0       8.0       7.0      6.0        2.0        4.0       1.0
# 1171   1.0       7.0       5.0      6.0        3.0        4.0       1.0
# 1183   1.0       5.0       7.0      6.0        2.0        4.0       1.0
# 1414   3.0       7.0       5.0      6.0        2.0        4.0       1.0
#
#       sys_clock   latency     area   power
# 0           3.2  0.000000    0.000   0.000
# 1           3.4  0.000000    0.000   0.000
# 2           3.7  0.000371  110.610  15.557
# 3           3.5  0.000171   41.608   4.072
# 4           2.0  0.000305  598.850  41.352
# ...         ...       ...      ...     ...
# 1160        3.3  0.000171   17.620   2.319
# 1170        3.3  0.000171   18.673   2.458
# 1171        3.3  0.000171   19.450   2.396
# 1183        3.3  0.000171   17.726   2.316
# 1414        3.3  0.000149   48.995   5.796
#
# [659 rows x 11 columns]

# %%
all_data.to_csv('./out/data/alldata.csv',index=False)
